# %%
# Define project information
# PROJECT_ID = "graphical-fort-306505" # @param {type:"string"}
# LOCATION = "us-central1" # @param {type:"string"}
PROJECT_ID = "wscc-dev-app-wsky" # @param {type:"string"}
LOCATION = "us-central1" # @param {type:"string"}

# Initialize Vertex AI
import vertexai
vertexai.init(project=PROJECT_ID, location=LOCATION)

# %%
from vertexai.preview.language_models import TextGenerationModel
generation_model = TextGenerationModel.from_pretrained("text-bison")

# %%
def get_medical_record(statement):
    template=f"""You are medical transcriber.Your job is extract
    patient's name, patient's demographic information,
    medications, past and current medical conditions from the
    following context and return a json response. Use the JSON
    template below.
    {{
    "patient": {{
    "name": "",
    "age": ,
    "gender": "",
    "race": "unidentified",
    "ethnicity": "unidentified",
    "marital_status": "unidentified",
    "occupation": "unidentified",
    "address": "unidentified",
    "phone_number": "unidentified",
    "email": "unidentified",
    "emergency_contact": "unidentified"
    }},
    "medical_history": {{
    "past_medical_conditions": [
    ""
    ],
    "current_medical_conditions": [
    ""
    ],
    "medications": [
    ],
    "hospitalizations": [
    {{
    "date": "",
    "reason": "",
    "hospital": ""
    }}
    ],
    "surgeries": [
    {{
    "date": "unidentified",
    "type": "unidentified",
    "hospital": "unidentified"
    }}
    ],
    "allergies": [
    "unidentified"
    ],
    "social_history": {{
    "tobacco_use": "unidentified",
    "alcohol_use": "unidentified",
    "drug_use": "unidentified"
    }},
    "family_history": {{
    "diabetes": "unidentified",
    "heart_disease": "unidentified",
    "stroke": "unidentified",
    "cancer": "unidentified",
    "other": "unidentified"
    }}
    }}
    }}
    context:{statement}
    response:
    """
    response=generation_model.predict(
        template,
        max_output_tokens=1024,
        temperature=0
    )
    answer = response.text
    return answer

# %%
print(get_medical_record("""The patient name is John Smith and is 56
years. Has diabetes and high cholestrol. His father was diabetic and
mother had undergone heart by-pass surgery.Has complaint about
intermittent chest pain. Has been on atorvastatin and insulin. Had
similar occurance in the past and was hospitalized between
09/30/2022 to 10/02/2022 at ABC Regional Hospital. Had recommended a
dosage of baby aspirin for one year
"""))
# Out:
#  {
#     "patient": {
#     "name": "John Smith",
#     "age": 56,
#     "gender": "unidentified",
#     "race": "unidentified",
#     "ethnicity": "unidentified",
#     "marital_status": "unidentified",
#     "occupation": "unidentified",
#     "address": "unidentified",
#     "phone_number": "unidentified",
#     "email": "unidentified",
#     "emergency_contact": "unidentified"
#     },
#     "medical_history": {
#     "past_medical_conditions": [
#     "diabetes",
#     "high cholesterol"
#     ],
#     "current_medical_conditions": [
#     "intermittent chest pain"
#     ],
#     "medications": [
#     "atorvastatin",
#     "insulin",
#     "baby aspirin"
#     ],
#     "hospitalizations": [
#     {
#     "date": "09/30/2022 to 10/02/2022",
#     "reason": "unidentified",
#     "hospital": "ABC Regional Hospital"
#     }
#     ],
#     "surgeries": [
#     {
#     "date": "unidentified",
#     "type": "unidentified",
#     "hospital": "unidentified"
#     }
#     ],
# ...

# %%
generation_model = TextGenerationModel.from_pretrained("text-bison")
def get_health_info(statement,question):
    template=f"""Answer the question given in the context below.
    Provide only specific answers without elaborate sentences.
    context:{statement}
    criteria:{question}
    answer:
    """
    response=generation_model.predict(
    template,
    max_output_tokens=1024,
    temperature=0
    )
    answer = response.text
    #print(answer)
    return answer

# %%
print(get_health_info("""The patient name is John Smith and is 56
years. Has diabetes and high cholestrol. His father was diabetic and
mother had undergone heart by-pass surgery.Has complaint about
intermittent chest pain. Has been on atorvastatin and insulin. Had
similar occurance in the past and was hospitalized between
09/30/2022 to 10/02/2022 at ABC Regional Hospital. Had recommended a
dosage of baby aspirin for one year""","what is patient's name ?"))
# Out:
#  John Smith

# %%
print(get_health_info("""The patient name is John Smith and is 56
years. Has diabetes and high cholestrol. His father was diabetic and
mother had undergone heart by-pass surgery.Has complaint about
intermittent chest pain. Has been on atorvastatin and insulin. Had
similar occurance in the past and was hospitalized between
09/30/2022 to 10/02/2022 at ABC Regional Hospital. Had recommended a
dosage of baby aspirin for one year""","what is patient's age ?"))

# %%
print(get_health_info("""The patient name is John Smith and is 56
years. Has diabetes and high cholestrol. His father was diabetic and
mother had undergone heart by-pass surgery.Has complaint about
intermittent chest pain. Has been on atorvastatin and insulin. Had
similar occurance in the past and was hospitalized between
09/30/2022 to 10/02/2022 at ABC Regional Hospital. Had recommended a
dosage of baby aspirin for one year""","what medication the patient ison ?"))
# Out:
#  Atorvastatin and insulin

# %%
print(get_health_info("""The patient name is John Smith and is 56
years. Has diabetes and high cholestrol. His father was diabetic and
mother had undergone heart by-pass surgery.Has complaint about
intermittent chest pain. Has been on atorvastatin and insulin. Had
similar occurance in the past and was hospitalized between
09/30/2022 to 10/02/2022 at ABC Regional Hospital. Had recommended a
dosage of baby aspirin for one year""","what is patient's complaint?"))
# Out:
#  Intermittent chest pain

# %%
print(get_health_info("""The patient name is John Smith and is 56
years. Has diabetes and high cholestrol. His father was diabetic and
mother had undergone heart by-pass surgery.Has complaint about
intermittent chest pain. Has been on atorvastatin and insulin. Had
similar occurance in the past and was hospitalized between
09/30/2022 to 10/02/2022 at ABC Regional Hospital. Had recommended a
dosage of baby aspirin for one year""","was he hospitalized in the past ?"))
# Out:
#  Yes

# %%
print(get_health_info("""The patient name is John Smith and is 56
years. Has diabetes and high cholestrol. His father was diabetic and
mother had undergone heart by-pass surgery.Has complaint about
intermittent chest pain. Has been on atorvastatin and insulin. Had
similar occurance in the past and was hospitalized between
09/30/2022 to 10/02/2022 at ABC Regional Hospital. Had recommended a
dosage of baby aspirin for one year""","was he hospitalized in the past and for what reason ?"))
# Out:
#  Yes, for chest pain

# %%
print(get_health_info("""The patient name is John Smith and is 56
years. Has diabetes and high cholestrol. His father was diabetic and
mother had undergone heart by-pass surgery.Has complaint about
intermittent chest pain. Has been on atorvastatin and insulin. Had
similar occurance in the past and was hospitalized between
09/30/2022 to 10/02/2022 at ABC Regional Hospital. Had recommended a
dosage of baby aspirin for one year""","Is there a family history of diabetes ?"))
# Out:
#  yes
